# %%
items = int(input("Enter number of items: "))
total = 0

for i in range(1, items + 1):
    price = float(input("Enter price of item " + str(i) + ": "))
    total = total + price

print("Total Bill:", total)

# Discount conditions
if total >= 1000:
    discount = total * 0.20
    print("20% Discount Applied:", discount)
elif total >= 500:
    discount = total * 0.10
    print("10% Discount Applied:", discount)
else:
    discount = 0
    print("No Discount")

final_bill = total - discount
print("Final Bill Amount:", final_bill)
# Out:
# Enter number of items:  5
# Enter price of item 1:  100
# Enter price of item 2:  500
# Enter price of item 3:  200
# Enter price of item 4:  487
# Enter price of item 5:  199
# Total Bill: 1486.0
# 20% Discount Applied: 297.2
# Final Bill Amount: 1188.8
